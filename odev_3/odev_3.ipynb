# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv("data01.csv")

data.head(100)
# Out:
#     group      ID  outcome  age  gendera        BMI  hypertensive  \
# 0       1  125047      0.0   72        1  37.588179             0
# 1       1  139812      0.0   75        2        NaN             0
# 2       1  109787      0.0   83        2  26.572634             0
# 3       1  130587      0.0   43        2  83.264629             0
# 4       1  138290      0.0   75        2  31.824842             1
# ..    ...     ...      ...  ...      ...        ...           ...
# 95      1  152651      0.0   94        1  26.224800             1
# 96      1  128156      0.0   70        1  25.662222             0
# 97      1  108287      0.0   63        2  37.261470             1
# 98      1  135809      0.0   68        1  34.527089             1
# 99      1  121435      0.0   88        1  14.858018             1
#
#     atrialfibrillation  CHD with no MI  diabetes  ...  Blood sodium  \
# 0                    0               0         1  ...    138.750000
# ...

# %%
M = data[data.hypertensive == 0]
B = data[data.hypertensive == 1]
# scatter plot
plt.scatter(M.age,M.gendera,color="red",label="bad",alpha= 0.2)
plt.scatter(B.age,B.gendera,color="green",label="good",alpha= 0.2)
plt.xlabel("age")
plt.ylabel("gendera")
plt.legend()
plt.show()

# %%
data.head()
# Out:
#    group      ID  outcome  age  gendera        BMI  hypertensive  \
# 0      1  125047      0.0   72        1  37.588179             0
# 1      1  139812      0.0   75        2        NaN             0
# 2      1  109787      0.0   83        2  26.572634             0
# 3      1  130587      0.0   43        2  83.264629             0
# 4      1  138290      0.0   75        2  31.824842             1
#
#    atrialfibrillation  CHD with no MI  diabetes  ...  Blood sodium  \
# 0                   0               0         1  ...    138.750000
# 1                   0               0         0  ...    138.888889
# 2                   0               0         0  ...    140.714286
# 3                   0               0         0  ...    138.500000
# 4                   0               0         0  ...    136.666667
#
#    Blood calcium    Chloride  Anion gap  Magnesium ion     PH  Bicarbonate  \
# 0       7.463636  109.166667  13.166667       2.618182  7.230    21.166667
# ...

# %%
from sklearn.impute import SimpleImputer

ipm = SimpleImputer(missing_values= np.NaN , strategy="mean")
ipm.fit(data)
data.head()
# Out:
#    group      ID  outcome  age  gendera        BMI  hypertensive  \
# 0      1  125047      0.0   72        1  37.588179             0
# 1      1  139812      0.0   75        2        NaN             0
# 2      1  109787      0.0   83        2  26.572634             0
# 3      1  130587      0.0   43        2  83.264629             0
# 4      1  138290      0.0   75        2  31.824842             1
#
#    atrialfibrillation  CHD with no MI  diabetes  ...  Blood sodium  \
# 0                   0               0         1  ...    138.750000
# 1                   0               0         0  ...    138.888889
# 2                   0               0         0  ...    140.714286
# 3                   0               0         0  ...    138.500000
# 4                   0               0         0  ...    136.666667
#
#    Blood calcium    Chloride  Anion gap  Magnesium ion     PH  Bicarbonate  \
# 0       7.463636  109.166667  13.166667       2.618182  7.230    21.166667
# ...

# %%
x = (x_data - np.min(x_data))/(np.max(x_data)-np.min(x_data))
# Out:
# /root/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /root/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.max(axis=None) will return a scalar max over the entire DataFrame. To retain the old behavior, use 'frame.max(axis=0)' or just 'frame.max()'
#   return reduction(axis=axis, out=out, **passkwargs)
# /root/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.3,random_state=1)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 3) # n_neighbors = k

knn.fit(x_train,y_train)

prediction = knn.predict(x_test)
print(" {} nn score: {} ".format(3,knn.score(x_test,y_test)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[135], line 5
#       1 from sklearn.neighbors import KNeighborsClassifier
#       3 knn = KNeighborsClassifier(n_neighbors = 3) # n_neighbors = k
# ----> 5 knn.fit(x_train,y_train)
#       7 prediction = knn.predict(x_test)
#       8 print(" {} nn score: {} ".format(3,knn.score(x_test,y_test)))
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/neighbors/_classification.py:215, in KNeighborsClassifier.fit(self, X, y)
#     196 """Fit the k-nearest neighbors classifier from the training dataset.
#     197
#     198 Parameters
#    (...)
#     211     The fitted k-nearest neighbors classifier.
#     212 """
#     213 self._validate_params()
# --> 215 return self._fit(X, y)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/neighbors/_base.py:454, in NeighborsBase._fit(self, X, y)
# ...

# %%
score_list = []
for each in range(1,15):
    knn2 = KNeighborsClassifier(n_neighbors = each)
    knn2.fit(x_train,y_train)
    score_list.append(knn2.score(x_test,y_test))
    
plt.plot(range(1,15),score_list)
plt.xlabel("k values")
plt.ylabel("accuracy")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 4
#       2 for each in range(1,15):
#       3     knn2 = KNeighborsClassifier(n_neighbors = each)
# ----> 4     knn2.fit(x_train,y_train)
#       5     score_list.append(knn2.score(x_test,y_test))
#       7 plt.plot(range(1,15),score_list)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/neighbors/_classification.py:215, in KNeighborsClassifier.fit(self, X, y)
#     196 """Fit the k-nearest neighbors classifier from the training dataset.
#     197
#     198 Parameters
#    (...)
#     211     The fitted k-nearest neighbors classifier.
#     212 """
#     213 self._validate_params()
# --> 215 return self._fit(X, y)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/neighbors/_base.py:454, in NeighborsBase._fit(self, X, y)
#     452 if self._get_tags()["requires_y"]:
# ...
